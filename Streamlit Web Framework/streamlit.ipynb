# %% [markdown]
# #### Introduction to Streamlit
#
# Streamlit is an open source app framework for Machine learning and data science projects. It allows you yo create beautiful web applications for your machine learning and data science projects with simple python scripts.

# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 558.9 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/9.9 MB 729.2 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/9.9 MB 729.2 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.0/9.9 MB 786.4 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.9 MB 883.4 kB/s eta 0:00:10
#    ------ --------------------------------- 1.6/9.9 MB 902.1 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.9 MB 923.6 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.9 MB 923.6 kB/s eta 0:00:09
# ...
