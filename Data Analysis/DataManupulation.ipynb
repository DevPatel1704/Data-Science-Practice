# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#       Name   Age Department   Salary   Join_Date
# 0    Alice  25.0         HR  50000.0  2015-03-01
# 1      Bob  30.0         IT  60000.0  2016-07-15
# 2  Charlie   NaN    Finance  55000.0  2017-10-30
# 3    David  40.0        NaN      NaN  2018-12-12
# 4      Eva  22.0         IT  62000.0         NaN

# %%
df.tail()
# Out:
#     Name   Age Department   Salary   Join_Date
# 3  David  40.0        NaN      NaN  2018-12-12
# 4    Eva  22.0         IT  62000.0         NaN
# 5  Frank  28.0  Marketing  58000.0  2020-09-18
# 6  Grace   NaN         HR      NaN  2021-11-01
# 7  Helen  35.0    Finance  61000.0  2019-06-25

# %%
df.describe()
# Out:
#             Age        Salary
# count   6.00000      6.000000
# mean   30.00000  57666.666667
# std     6.60303   4501.851471
# min    22.00000  50000.000000
# 25%    25.75000  55750.000000
# 50%    29.00000  59000.000000
# 75%    33.75000  60750.000000
# max    40.00000  62000.000000

# %%
df.dtypes
# Out:
# Name           object
# Age           float64
# Department     object
# Salary        float64
# Join_Date      object
# dtype: object

# %%
## Handling missing values 

df.isnull().any()
# Out:
# Name          False
# Age            True
# Department     True
# Salary         True
# Join_Date      True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           2
# Department    1
# Salary        2
# Join_Date     1
# dtype: int64

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#       Name   Age Department   Salary   Join_Date
# 0    Alice  25.0         HR  50000.0  2015-03-01
# 1      Bob  30.0         IT  60000.0  2016-07-15
# 2  Charlie   0.0    Finance  55000.0  2017-10-30
# 3    David  40.0          0      0.0  2018-12-12
# 4      Eva  22.0         IT  62000.0           0
# 5    Frank  28.0  Marketing  58000.0  2020-09-18
# 6    Grace   0.0         HR      0.0  2021-11-01
# 7    Helen  35.0    Finance  61000.0  2019-06-25

# %%
## filling missing valueswith mean of the column 

df['Salary_fillNA'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#       Name   Age Department   Salary   Join_Date  Salary_fillNA
# 0    Alice  25.0         HR  50000.0  2015-03-01   50000.000000
# 1      Bob  30.0         IT  60000.0  2016-07-15   60000.000000
# 2  Charlie   NaN    Finance  55000.0  2017-10-30   55000.000000
# 3    David  40.0        NaN      NaN  2018-12-12   57666.666667
# 4      Eva  22.0         IT  62000.0         NaN   62000.000000
# 5    Frank  28.0  Marketing  58000.0  2020-09-18   58000.000000
# 6    Grace   NaN         HR      NaN  2021-11-01   57666.666667
# 7    Helen  35.0    Finance  61000.0  2019-06-25   61000.000000

# %%
df.dtypes
# Out:
# Name              object
# Age              float64
# Department        object
# Salary           float64
# Join_Date         object
# Salary_fillNA    float64
# dtype: object

# %%
## Renaming columns 

df.rename(columns={'Join_Date':'Sales-Date'})
# Out:
#       Name   Age Department   Salary  Sales-Date  Salary_fillNA
# 0    Alice  25.0         HR  50000.0  2015-03-01   50000.000000
# 1      Bob  30.0         IT  60000.0  2016-07-15   60000.000000
# 2  Charlie   NaN    Finance  55000.0  2017-10-30   55000.000000
# 3    David  40.0        NaN      NaN  2018-12-12   57666.666667
# 4      Eva  22.0         IT  62000.0         NaN   62000.000000
# 5    Frank  28.0  Marketing  58000.0  2020-09-18   58000.000000
# 6    Grace   NaN         HR      NaN  2021-11-01   57666.666667
# 7    Helen  35.0    Finance  61000.0  2019-06-25   61000.000000

# %%
## Chnage the datatypes

df['value_new'] = df['Age'].fillna(df['Age'].mean()).astype(int)

df.rename(columns={'value_new':'Age_new'})
# Out:
#       Name   Age Department   Salary   Join_Date  Salary_fillNA  Age_new
# 0    Alice  25.0         HR  50000.0  2015-03-01   50000.000000       25
# 1      Bob  30.0         IT  60000.0  2016-07-15   60000.000000       30
# 2  Charlie   NaN    Finance  55000.0  2017-10-30   55000.000000       30
# 3    David  40.0        NaN      NaN  2018-12-12   57666.666667       40
# 4      Eva  22.0         IT  62000.0         NaN   62000.000000       22
# 5    Frank  28.0  Marketing  58000.0  2020-09-18   58000.000000       28
# 6    Grace   NaN         HR      NaN  2021-11-01   57666.666667       30
# 7    Helen  35.0    Finance  61000.0  2019-06-25   61000.000000       35

# %%
df['New Value'] = df['Age'].apply(lambda x:x*2)
df.head()
# Out:
#       Name   Age Department   Salary   Join_Date  Salary_fillNA  value_new  \
# 0    Alice  25.0         HR  50000.0  2015-03-01   50000.000000         25
# 1      Bob  30.0         IT  60000.0  2016-07-15   60000.000000         30
# 2  Charlie   NaN    Finance  55000.0  2017-10-30   55000.000000         30
# 3    David  40.0        NaN      NaN  2018-12-12   57666.666667         40
# 4      Eva  22.0         IT  62000.0         NaN   62000.000000         22
#
#    New Value
# 0       50.0
# 1       60.0
# 2        NaN
# 3       80.0
# 4       44.0
